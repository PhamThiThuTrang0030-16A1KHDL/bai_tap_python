[76.0, 200.0], [74.0, 220.0], [76.0, 170.0], [78.0, 220.0], [74.0, 190.0], [76.0, 220.0], [72.0, 205.0], [74.0, 200.0], [76.0, 250.0], [74.0, 225.0], [75.0, 215.0], [78.0, 210.0], [75.0, 215.0], [72.0, 195.0], [74.0, 200.0], [72.0, 194.0], [74.0, 220.0], [70.0, 180.0], [71.0, 180.0], [70.0, 170.0], [75.0, 195.0], [71.0, 180.0], [71.0, 170.0], [73.0, 206.0], [72.0, 205.0], [71.0, 200.0], [73.0, 225.0], [72.0, 201.0], [75.0, 225.0], [70.0, 226.0], [74.0, 233.0], [74.0, 180.0], [75.0, 225.0], [73.0, 180.0], [77.0, 220.0], [73.0, 180.0], [76.0, 237.0], [75.0, 215.0], [74.0, 190.0], [76.0, 235.0], [75.0, 190.0], [73.0, 180.0], [71.0, 165.0], [76.0, 195.0], [75.0, 200.0], [72.0, 190.0], [71.0, 190.0], [77.0, 185.0], [73.0, 185.0], [74.0, 205.0], [71.0, 190.0], [72.0, 205.0], [74.0, 206.0], [75.0, 220.0], [73.0, 208.0], [72.0, 170.0], [75.0, 195.0], [75.0, 210.0], [74.0, 190.0], [72.0, 211.0], [74.0, 230.0], [71.0, 170.0], [70.0, 185.0], [75.0, 230.0], [74.0, 185.0], [77.0, 241.0], [77.0, 225.0], [75.0, 210.0], [75.0, 175.0], [78.0, 230.0], [75.0, 200.0], [76.0, 215.0], [73.0, 198.0], [75.0, 226.0], [75.0, 278.0], [79.0, 215.0], [77.0, 230.0], [76.0, 240.0], [71.0, 184.0], [75.0, 219.0], [74.0, 170.0], [69.0, 218.0], [71.0, 190.0], [76.0, 225.0], [72.0, 220.0], [72.0, 176.0], [70.0, 190.0], [72.0, 197.0], [73.0, 204.0], [71.0, 167.0], [72.0, 180.0], [71.0, 195.0], [73.0, 220.0], [72.0, 215.0], [73.0, 185.0], [74.0, 190.0], [74.0, 205.0], [72.0, 205.0], [73.0, 200.0], [75.0, 200.0], [74.0, 210.0], [74.0, 215.0], [77.0, 200.0], [75.0, 205.0], [73.0, 21 ...

# %%
# 1
np_baseball = np.array(baseball)
print(np_baseball)
# Out:
# [[ 74. 180.]
#  [ 74. 215.]
#  [ 72. 210.]
#  ...
#  [ 75. 205.]
#  [ 75. 190.]
#  [ 73. 195.]]

# %%
# 2
print(np_baseball[50,:])
# Out:
# [ 70. 195.]

# %%
# 3
np_weight = np.array(np_baseball[:,1])
print(np_weight)
# Out:
# [180. 215. 210. ... 205. 190. 195.]

# %%
# 4
print('chiều cao của vận động viên thứ 124:',np_baseball[124,0],'inch')
# 5
average_weight = np.mean(np_baseball[:,1])
average_height = np.mean(np_baseball[:,0])
print('chiều cao trung bình của các cầu thủ:',average_weight)
print('cân nặng trung bình của các cầu thủ:',average_weight)
# Out:
# chiều cao của vận động viên thứ 124: 80.0 inch
# chiều cao trung bình của các cầu thủ: 201.6892545982575
# cân nặng trung bình của các cầu thủ: 201.6892545982575

# %%
# 6. Bạn nhận xét gì về mối tương quan giữa chiều cao và cân nặng của các cầu thủ: có/không có tương quan, tương quan thuận/nghịch.
correlation = np.corrcoef(np_baseball[:,0],np_baseball[:,1])[0, 1]
print(correlation)
if correlation > 0:
    correlation_type = "tương quan thuận"
elif correlation < 0:
    correlation_type = "tương quan nghịch"
else:
    correlation_type = "không có tương quan"
print(correlation_type)
# Out:
# 0.5318858630270028
# tương quan thuận
